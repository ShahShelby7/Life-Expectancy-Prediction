# %% [markdown]
# ### IMPORTING PANDAS AND NUMPY LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### READING CSV FILE

# %%
df=pd.read_csv("LifeExpectancyData.csv")

# %% [markdown]
# ### DATA PREPOCESSING

# %%
df.isnull().count()
df.interpolate(inplace=True)

# %%
df.isna().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
df.head(7)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
# 5  Afghanistan  2010  Developing              58.8            279.0
# 6  Afghanistan  2009  Developing              58.6            281.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# ...

# %%
df.tail(7)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2931  Zimbabwe  2006  Developing              45.4              7.0
# 2932  Zimbabwe  2005  Developing              44.6            717.0
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2931             28     4.57               34.262169         68.0       212
# 2932             28     4.14                8.717409         65.0       420
# 2933             27     4.36                0.000000         68.0        31
# 2934             26     4.06                0.000000          7.0       998
# ...

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2938 non-null   float64
#  4   Adult Mortality                  2938 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2938 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2938 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2938 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2938.000000      2938.000000    2938.000000
# mean   2007.518720         69.214874       164.744554      30.303948
# std       4.613841          9.510819       124.226596     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.000000       144.000000       3.000000
# 75%    2012.000000         75.600000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2938.000000             2938.000000  2938.000000    2938.000000
# mean      4.550179              738.251295    78.528421    2419.592240
# std       3.994827             1987.914858    25.183772   11467.272489
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df[df["Life expectancy "]>70]
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 16     Albania  2015  Developing              77.8             74.0
# 17     Albania  2014  Developing              77.5              8.0
# 18     Albania  2013  Developing              77.2             84.0
# 19     Albania  2012  Developing              76.9             86.0
# 20     Albania  2011  Developing              76.6             88.0
# ...        ...   ...         ...               ...              ...
# 2885  Viet Nam  2004  Developing              74.2            136.0
# 2886  Viet Nam  2003  Developing              74.0            137.0
# 2887  Viet Nam  2002  Developing              73.8            137.0
# 2888  Viet Nam  2001  Developing              73.6            138.0
# 2889  Viet Nam  2000  Developing              73.4            139.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
df["Life expectancy "].mode()
# Out:
# 0    73.0
# Name: Life expectancy , dtype: float64

# %%
df["Country"].value_counts()
# Out:
# Country
# Afghanistan              16
# Peru                     16
# Nicaragua                16
# Niger                    16
# Nigeria                  16
#                          ..
# Niue                      1
# San Marino                1
# Nauru                     1
# Saint Kitts and Nevis     1
# Dominica                  1
# Name: count, Length: 193, dtype: int64

# %%
df1=df.groupby(["Country"])
df1.first()
# Out:
#                                     Year      Status  Life expectancy   \
# Country
# Afghanistan                         2015  Developing              65.0
# Albania                             2015  Developing              77.8
# Algeria                             2015  Developing              75.6
# Angola                              2015  Developing              52.4
# Antigua and Barbuda                 2015  Developing              76.4
# ...                                  ...         ...               ...
# Venezuela (Bolivarian Republic of)  2015  Developing              74.1
# Viet Nam                            2015  Developing              76.0
# Yemen                               2015  Developing              65.7
# Zambia                              2015  Developing              61.8
# Zimbabwe                            2015  Developing              67.0
#
#                                     Adult Mortality  infant deaths  Alcohol  \
# Country
# ...

# %%
df.groupby('Life expectancy ')[' BMI '].transform(lambda x:x-x.mean())
# Out:
# 0      -19.107692
# 1        0.971429
# 2        0.471429
# 3       -1.420000
# 4      -10.785714
#           ...
# 2933     3.700000
# 2934    -0.350000
# 2935    -0.300000
# 2936     9.100000
# 2937     2.140000
# Name:  BMI , Length: 2938, dtype: float64

# %% [markdown]
# ### DATA VISUALISATION

# %% [markdown]
# ### Scatter plot

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Alcohol'], df['Adult Mortality'])
plt.title('Relationship between Alcohol and Adult Mortality')
plt.xlabel('Alcohol consumption')
plt.ylabel('Adult Mortality')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Pie chart

# %%
Country_Status = df['Status'].value_counts()

# Plotting a basic pie chart
plt.figure(figsize=(8, 6))
plt.pie(Country_Status, labels=Country_Status.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Status of country')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ### Scatter Plot 2

# %%
import matplotlib.pyplot as plt

# Plotting a basic scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(df['Alcohol'], df['Life expectancy '], color='blue', alpha=0.5)
plt.title('Relationship between Alcohol Consumption and Life expectancy')
plt.xlabel('Alcohol Consumption')
plt.ylabel('Life expectancy')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Histogram plot

# %%
import matplotlib.pyplot as plt

# Plotting a basic histogram
plt.figure(figsize=(8, 6))
plt.hist(df['GDP'], bins=7, color='green', edgecolor='black')
plt.title('Distribution of GDP across countries')
plt.xlabel('GDP')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Area plot

# %%
import matplotlib.pyplot as plt

# Sorting the data by 'percentage expenditure'
sorted_data = df.sort_values(by='percentage expenditure')

# Calculating the cumulative sum of 'percentage expenditure'
cumulative_sum = sorted_data['percentage expenditure'].cumsum()

# Plotting a basic area chart
plt.figure(figsize=(8, 6))
plt.fill_between(sorted_data.index, cumulative_sum, color='skyblue', alpha=0.4)
plt.plot(sorted_data.index, cumulative_sum, color='Slateblue', alpha=0.6, linewidth=2)
plt.title('Cumulative Sum of percentage expenditure ')
plt.xlabel('Index')
plt.ylabel('Cumulative Sum')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Box plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Setting up the figure size
plt.figure(figsize=(8, 6))

# Creating a box plot with different colors for each Age
sns.boxplot(x='Year', y=' BMI ', data=df, palette='Set3')

# Adding title and labels
plt.title('Distribution of  BMI  by Year')
plt.xlabel('Year')
plt.ylabel(' BMI  ')

# Displaying the plot
plt.show()

# %% [markdown]
# ### Bar Graph

# %%
import matplotlib.pyplot as plt

# Counting the occurrences of each Age level
Age_counts = df['Life expectancy '].value_counts()

# Plotting a basic bar chart
plt.figure(figsize=(8, 6))
plt.bar(Age_counts.index, Age_counts.values, color='skyblue')

# Adding title and labels
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Count')

# Displaying the plot
plt.show()

# %% [markdown]
# ### Regression Plot 1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plotting a basic regression plot
plt.figure(figsize=(8, 6))
sns.regplot(x='Adult Mortality', y='Life expectancy ', data=df, scatter_kws={'alpha':0.5, 'color':'blue'}, line_kws={'color':'red'})

# Adding title and labels
plt.title('Regression Plot of Adult Mortality vs. Life expectancy ')
plt.xlabel('Adult Mortality ')
plt.ylabel('Life expectancy ')

# Save the plot as an image file with high resolution
plt.savefig('linear_graph.png', dpi=2000)

# Displaying the plot
plt.show()

# %% [markdown]
# ### Distplot

# %%
import seaborn as sns
sns.distplot(df["Year"])
plt.show()
# Out:
# C:\Users\SHAHUL\AppData\Local\Temp\ipykernel_9944\1104371616.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Year"])

# %% [markdown]
# ### Bubble plot

# %%
import matplotlib.pyplot as plt

# Data for the bubble plot
x = df['Alcohol']  # x-axis: Alcohol content
y = df[' BMI ']  # y-axis:  BMI 
z = df['Life expectancy ']  # bubble size: Life expectancy 

# Plotting the bubble plot
plt.figure(figsize=(10, 8))
bubble = plt.scatter(x, y, s=z*0.5, alpha=0.5)

# Adding labels and title
plt.title('Bubble Plot: Alcohol Consumption vs.  BMI ')
plt.xlabel('Alcohol Content')
plt.ylabel(' BMI ')

# Adding a colorbar
plt.colorbar(bubble, label='Life expectancy ')

# Displaying the plot
plt.show()

# %% [markdown]
# ### Regression plot 2

# %%
fig, axs = plt.subplots(4, 4, figsize=(10, 8))
for Country, ax in zip(set(df["Country"]), axs.flat):
    Countries =df[df["Country"] == Country]
    sns.regplot(x =Countries['Income composition of resources'] , y =Countries["Life expectancy "],color ='red',ax=ax).set_title(Country)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.LINEAR REGRESSION

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model
reg=linear_model.LinearRegression()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
x=df.drop(["Life expectancy ","Country","Status","Year"],axis=1)
y=df["Life expectancy "]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=70)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (2350, 18)
# (2350,)
# (588, 18)
# (588,)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=reg.predict(x_test)
pred
# Out:
# array([72.6649736 , 76.06575987, 57.82057197, 74.0995542 , 75.99819589,
#        75.80507699, 57.15881986, 71.69394636, 68.14785422, 46.6310533 ,
#        80.53243638, 70.60201175, 59.94838741, 70.51472431, 60.52597098,
#        70.79286426, 79.2978651 , 84.47888559, 65.32641135, 76.31366853,
#        74.88702889, 61.88550077, 54.82233788, 62.26084103, 65.13841047,
#        62.09934252, 58.60416242, 77.73492421, 82.36137587, 58.78824487,
#        47.54308637, 73.70724301, 79.59856812, 73.75317513, 79.88110065,
#        74.10003032, 66.91880144, 66.66374206, 76.00164766, 73.26704687,
#        73.25986261, 73.85648302, 69.45390781, 61.05356772, 79.39390399,
#        77.66539741, 67.56860672, 75.94902463, 71.27316032, 53.10905775,
#        71.55649537, 71.02563148, 72.89460709, 68.01171322, 77.20200789,
#        76.13775973, 73.57639895, 67.97350972, 60.24582815, 74.42928252,
#        73.2813182 , 74.89018604, 68.46380766, 53.07311264, 62.5646476 ,
# ...

# %%
y_pred = reg.predict(x_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("R-squared:",r2)
# Out:
# Mean Absolute Error: 3.0314541994814834
# Mean Squared Error: 17.510151234400585
# Root Mean Squared Error: 4.184513261348395
# R-squared: 0.8012416266635316

# %% [markdown]
# ### 2.Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor(random_state=42)
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([78. , 74. , 56.2, 72.5, 78.7, 75.8, 58.3, 67.2, 66.6, 56.5, 81.5,
#        59.3, 61.4, 75.9, 59.6, 64.8, 79.6, 88. , 63.1, 75.1, 75.4, 54. ,
#        52.9, 62.1, 65.5, 59.3, 57.4, 81.7, 79.4, 53.1, 52.5, 69.8, 87. ,
#        73.3, 79.7, 73.3, 72.4, 71.8, 79.3, 72.9, 69.6, 74.5, 71.5, 61.4,
#        81.7, 78.9, 67.5, 72.3, 69.4, 51.7, 68.7, 74.6, 72.5, 68.4, 79.6,
#        78.6, 72.5, 68.1, 67.9, 82. , 68.1, 77.7, 65.5, 59.4, 62. , 46. ,
#        71.5, 59.9, 53.1, 81. , 51.3, 65.2, 67.7, 62.8, 53.5, 71.9, 61.1,
#        62.8, 68.7, 44.8, 69.2, 73.3, 79.3, 82.3, 52.6, 57.3, 74. , 71. ,
#        57.4, 72.5, 67.9, 62.9, 76. , 79.8, 71.7, 74. , 62.5, 55. , 63.5,
#        68.1, 74. , 76.5, 69.7, 79.9, 76.3, 68.3, 66.3, 61.4, 74.5, 72.2,
#        75.6, 69.4, 76.9, 71.6, 69. , 74.8, 64.8, 63. , 61.2, 67.5, 62.3,
#        44. , 67.1, 53.6, 58.9, 68.5, 71.1, 73.3, 72.1, 52.1, 51.6, 64.4,
#        68.5, 73.9, 55.7, 57.3, 75.4, 63.2, 72.2, 72.7, 70. , 51.2, 75.4,
# ...

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)
print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print("Root Mean Squared Error:", rmse)
print("R-squared:",r2)
# Out:
# Mean Absolute Error: 1.5609693877551019
# Mean Squared Error: 7.896075680272109
# Root Mean Squared Error: 2.8099956726429505
# R-squared: 0.9103713533399269

# %% [markdown]
# ### 3.RANDOM FOREST REGRESSSOR

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(random_state=42)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([73.237 , 73.632 , 55.695 , 73.157 , 77.482 , 75.896 , 56.618 ,
#        67.296 , 72.529 , 55.019 , 83.648 , 59.579 , 61.621 , 74.696 ,
#        59.444 , 65.053 , 80.061 , 83.527 , 64.06  , 74.941 , 75.454 ,
#        53.488 , 54.181 , 62.051 , 65.33  , 58.951 , 60.376 , 80.828 ,
#        80.116 , 56.145 , 52.52  , 70.612 , 82.336 , 73.61  , 80.048 ,
#        74.085 , 73.434 , 73.309 , 78.878 , 72.411 , 70.634 , 74.446 ,
#        71.488 , 62.609 , 82.158 , 78.822 , 67.68  , 72.823 , 69.565 ,
#        53.128 , 69.003 , 74.564 , 73.325 , 69.197 , 80.843 , 79.904 ,
#        74.005 , 68.792 , 73.603 , 82.079 , 67.489 , 77.112 , 66.4835,
#        60.285 , 55.188 , 47.053 , 72.164 , 59.941 , 56.342 , 81.979 ,
#        54.25  , 66.593 , 72.38  , 60.847 , 52.921 , 72.789 , 61.175 ,
#        61.628 , 68.809 , 44.638 , 66.9995, 73.309 , 79.654 , 82.275 ,
#        52.824 , 57.381 , 73.342 , 70.996 , 59.611 , 72.84  , 68.126 ,
# ...

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("R-squared:",r2)
# Out:
# Mean Absolute Error: 1.208349489795919
# Mean Squared Error: 3.851453173894555
# Root Mean Squared Error: 1.9625119550959569
# R-squared: 0.9562820127834798
